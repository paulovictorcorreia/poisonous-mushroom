# %%
# %cd ..
# Out:
# c:\Users\Paulo\Documents\Projects\poisonous-mushroom

# %%
# !python poisonous_mushroom_analysis/stages/data_load.py --config=params.yaml
# Out:
# ...
# Extracting datasets
# Downloading...
# From (original): https://drive.google.com/uc?id=1v5PlKhhafsmWEvRUBj4Zpo2kkNDDR4HY
# From (redirected): https://drive.google.com/uc?id=1v5PlKhhafsmWEvRUBj4Zpo2kkNDDR4HY&confirm=t&uuid=a5ebc93a-b9fb-43a5-b598-9a42ec93e184
# To: c:\Users\Paulo\Documents\Projects\poisonous-mushroom\data\raw\mushroom.zip
#
#   0%|          | 0.00/86.3M [00:00<?, ?B/s]
#   1%|          | 524k/86.3M [00:00<00:37, 2.30MB/s]
#   2%|▏         | 1.57M/86.3M [00:00<00:21, 3.92MB/s]
#   3%|▎         | 2.62M/86.3M [00:00<00:18, 4.59MB/s]
#   4%|▎         | 3.15M/86.3M [00:00<00:17, 4.72MB/s]
#   5%|▍         | 4.19M/86.3M [00:00<00:16, 5.00MB/s]
#   6%|▌         | 5.24M/86.3M [00:01<00:15, 5.11MB/s]
#   7%|▋         | 6.29M/86.3M [00:01<00:15, 5.21MB/s]
#   8%|▊         | 6.82M/86.3M [00:01<00:15, 5.20MB/s]
#   9%|▉         | 7.86M/86.3M [00:01<00:14, 5.30MB/s]
#  10%|█         | 8.91M/86.3M [00:01<00:14, 5.27MB/s]
#  12%|█▏        | 9.96M/86.3M [00:02<00:14, 5.28MB/s]
# ...

# %%
# !python poisonous_mushroom_analysis/stages/preprocessing.py --config=params.yaml
